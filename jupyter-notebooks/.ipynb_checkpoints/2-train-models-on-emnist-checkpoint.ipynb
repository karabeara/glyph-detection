# %% [markdown]
# # Train Classifier on Handwritten Character Dataset EMNIST
# ### Find more information about the Extended MNIST (EMNIST) dataset here:
# - https://www.nist.gov/itl/products-and-services/emnist-dataset

# %% [markdown]
# ## Importing Libraries

# %%
from mnist import MNIST # python library which has the EMNIST and MNIST datasets (pip install python-mist)

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from emnist import extract_training_samples
from emnist import list_datasets
from emnist import extract_test_samples
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
list_datasets()
# Out:
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %% [markdown]
# ## Extracting the Trainable Dataset and Image Pre-Processing

# %%
train_images, train_labels = extract_training_samples('balanced')
print(train_images.shape)
print(train_labels.shape)
# Out:
# (112800, 28, 28)
# (112800,)

# %%
test_images, test_labels = extract_test_samples('balanced')
print(test_images.shape)
print(test_labels.shape)
# Out:
# (18800, 28, 28)
# (18800,)

# %%
train_images = tf.keras.utils.normalize(train_images, axis = 1)
test_images = tf.keras.utils.normalize(test_images, axis = 1)

train_images = np.expand_dims(train_images, axis=3)
test_images = np.expand_dims(test_images, axis=3)

# %%
import matplotlib.pyplot as plt
i = 8
plt.imshow(train_images[i],cmap = plt.cm.binary)
plt.xlabel(train_labels[i])
plt.show()

# %%
# specify the arguments
rotation_range_val = 15
width_shift_val = 0.10
height_shift_val = 0.10

# %%
# create the class object
train_datagen = ImageDataGenerator(rotation_range = rotation_range_val,
                             width_shift_range = width_shift_val,
                             height_shift_range = height_shift_val)

# %%
# fit the generator
train_datagen.fit(train_images.reshape(train_images.shape[0], 28, 28, 1))

# %%
# define number of rows & columns
num_row = 4
num_col = 8
num= num_row*num_col

# %%
# plot before
print('BEFORE:\n')
# plot images
fig1, axes1 = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(num):
     ax = axes1[i//num_col, i%num_col]
     ax.imshow(train_images[i], cmap='gray_r')
     ax.set_title('Label: {}'.format(train_labels[i]))
plt.tight_layout()
plt.show()
# Out:
# BEFORE:

# %%
# plot after
print('AFTER:\n')
fig2, axes2 = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for X, Y in train_datagen.flow(train_images.reshape(train_images.shape[0], 28, 28, 1),train_labels.reshape(train_labels.shape[0], 1),batch_size=num,shuffle=False):
     for i in range(0, num):
          ax = axes2[i//num_col, i%num_col]
          ax.imshow(X[i].reshape(28,28), cmap='gray_r')
          ax.set_title('Label: {}'.format(int(Y[i])))
     break
plt.tight_layout()
plt.show()
# Out:
# AFTER:

# %%
val_datagen = ImageDataGenerator()
val_datagen.fit(test_images.reshape(test_images.shape[0], 28, 28, 1))
val_datagen

# %% [markdown]
# ## Creating the Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1), padding='same'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(47, activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 6, 6, 64)         0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 128)         73856
#
#  max_pooling2d_14 (MaxPoolin  (None, 2, 2, 128)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten_4 (Flatten)         (None, 512)               0
#
#  dense_12 (Dense)            (None, 256)               131328
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dense_14 (Dense)            (None, 47)                6063
#
# =================================================================
# Total params: 262,959
# Trainable params: 262,959
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
history = model.fit(train_datagen.flow(train_images, train_labels, batch_size=1024),
         validation_data= val_datagen.flow(test_images, test_labels,
         batch_size=32), epochs= 20)
# Out:
# Epoch 1/20
# 111/111 [==============================] - 45s 397ms/step - loss: 2.2384 - accuracy: 0.3845 - val_loss: 0.8443 - val_accuracy: 0.7397
# Epoch 2/20
# 111/111 [==============================] - 44s 395ms/step - loss: 0.9936 - accuracy: 0.6920 - val_loss: 0.5701 - val_accuracy: 0.8159
# Epoch 3/20
# 111/111 [==============================] - 47s 419ms/step - loss: 0.7569 - accuracy: 0.7564 - val_loss: 0.4951 - val_accuracy: 0.8328
# Epoch 4/20
# 111/111 [==============================] - 44s 397ms/step - loss: 0.6585 - accuracy: 0.7835 - val_loss: 0.4582 - val_accuracy: 0.8463
# Epoch 5/20
# 111/111 [==============================] - 47s 419ms/step - loss: 0.5958 - accuracy: 0.8007 - val_loss: 0.4274 - val_accuracy: 0.8556
# Epoch 6/20
# 111/111 [==============================] - 45s 408ms/step - loss: 0.5534 - accuracy: 0.8114 - val_loss: 0.4051 - val_accuracy: 0.8614
# Epoch 7/20
# 111/111 [==============================] - 45s 407ms/step - loss: 0.5223 - accuracy: 0.8210 - val_loss: 0.4016 - val_accuracy: 0.8636
# Epoch 8/20
# 111/111 [==============================] - 46s 417ms/step - loss: 0.4960 - accuracy: 0.8303 - val_loss: 0.3851 - val_accuracy: 0.8664
# Epoch 9/20
# 111/111 [==============================] - 44s 399ms/step - loss: 0.4794 - accuracy: 0.8345 - val_loss: 0.3753 - val_accuracy: 0.8721
# Epoch 10/20
# 111/111 [==============================] - 45s 405ms/step - loss: 0.4614 - accuracy: 0.8400 - val_loss: 0.3626 - val_accuracy: 0.8761
# Epoch 11/20
# 111/111 [==============================] - 46s 409ms/step - loss: 0.4488 - accuracy: 0.8423 - val_loss: 0.3589 - val_accuracy: 0.8746
# Epoch 12/20
# 111/111 [==============================] - 46s 410ms/step - loss: 0.4376 - accuracy: 0.8464 - val_loss: 0.3663 - val_accuracy: 0.8723
# Epoch 13/20
# 111/111 [==============================] - 48s 428ms/step - loss: 0.4310 - accuracy: 0.8492 - val_loss: 0.3533 - val_accuracy: 0.8769
# Epoch 14/20
# 111/111 [==============================] - 54s 488ms/step - loss: 0.4190 - accuracy: 0.8525 - val_loss: 0.3502 - val_accuracy: 0.8778
# Epoch 15/20
# 111/111 [==============================] - 48s 434ms/step - loss: 0.4133 - accuracy: 0.8551 - val_loss: 0.3490 - val_accuracy: 0.8752
# Epoch 16/20
# 111/111 [==============================] - 45s 404ms/step - loss: 0.4065 - accuracy: 0.8551 - val_loss: 0.3408 - val_accuracy: 0.8819
# Epoch 17/20
# 111/111 [==============================] - 43s 386ms/step - loss: 0.3947 - accuracy: 0.8589 - val_loss: 0.3484 - val_accuracy: 0.8772
# Epoch 18/20
# 111/111 [==============================] - 44s 397ms/step - loss: 0.3943 - accuracy: 0.8579 - val_loss: 0.3344 - val_accuracy: 0.8822
# Epoch 19/20
# 111/111 [==============================] - 43s 387ms/step - loss: 0.3847 - accuracy: 0.8616 - val_loss: 0.3384 - val_accuracy: 0.8807
# Epoch 20/20
# 111/111 [==============================] - 44s 394ms/step - loss: 0.3815 - accuracy: 0.8627 - val_loss: 0.3262 - val_accuracy: 0.8836

# %%
scores = model.evaluate(test_images,test_labels)
# Out:
# 588/588 [==============================] - 2s 4ms/step - loss: 0.3262 - accuracy: 0.8836

# %%
print("Accuracy: %.2f%%"%(scores[1]*100))
# Out:
# Accuracy: 88.36%

# %% [markdown]
# ## Creating the Model History Graphs

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.grid()
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.grid()
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Saving the Model

# %%
model.save("/Users/karabressler/Jupyter Notebooks/emnist-balanced-saved-model")
# Out:
# INFO:tensorflow:Assets written to: /Users/karabressler/Jupyter Notebooks/emnist-balanced-saved-model/assets
